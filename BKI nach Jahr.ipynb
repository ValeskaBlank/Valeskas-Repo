# %%
import pandas as pd

# %%
dfbki = pd.read_excel("Excel-Files/BKIJahr.xlsx")
dfbki
# Out:
#    Zürcher Index der Wohnbaukosten      Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                              NaN             NaN        NaN        NaN
# 1                      Bezeichnung           Basis       Jahr     Stand¹
# 2                               CH            1939       1939        100
# 3                               CH            1939       1940      112.4
# 4                               CH            1939       1941      129.6
# 5                               CH            1939       1942        146
# 6                               CH            1939       1943      152.4
# 7                               CH            1939       1944      157.9
# 8                               CH            1939       1945      163.7
# 9                               CH            1939       1946      176.7
# 10                              CH            1939       1947      194.2
# 11                              CH            1939       1948      197.1
# ...

# %%
dfbki.drop(dfbki.index[2:63], inplace=True)
dfbki
# Out:
#    Zürcher Index der Wohnbaukosten      Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                              NaN             NaN        NaN        NaN
# 1                      Bezeichnung           Basis       Jahr     Stand¹
# 63                              CH            1939       2000      887.1
# 64                              CH            1939       2001      929.3
# 65                              CH            1939       2002      928.4
# 66                              CH            1939       2003      899.2
# 67                              CH            1939       2004      907.6
# 68                              CH            1939       2005      929.5
# 69                              CH            1939       2006      944.5
# 70                              CH            1939       2007      987.4
# 71                              CH            1939       2008     1026.8
# 72                              CH            1939       2009     1030.7
# ...

# %%
dfbki = dfbki.reset_index()
dfbki
# Out:
#     index Zürcher Index der Wohnbaukosten      Unnamed: 1 Unnamed: 2  \
# 0       0                             NaN             NaN        NaN
# 1       1                     Bezeichnung           Basis       Jahr
# 2      63                              CH            1939       2000
# 3      64                              CH            1939       2001
# 4      65                              CH            1939       2002
# 5      66                              CH            1939       2003
# 6      67                              CH            1939       2004
# 7      68                              CH            1939       2005
# 8      69                              CH            1939       2006
# 9      70                              CH            1939       2007
# 10     71                              CH            1939       2008
# 11     72                              CH            1939       2009
# 12     73                              CH            1939       2010
# ...

# %%
dfbki.drop(dfbki.index[25:29], inplace=True)
dfbki.tail(5)
# Out:
#     index Zürcher Index der Wohnbaukosten Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 20     81                              CH       1939       2018     1036.8
# 21     82                              CH       1939       2019     1046.3
# 22     83                              CH       1939       2020     1045.6
# 23     84                              CH       1939       2021     1057.7
# 24     85                              CH       1939       2022     1128.6
#
#     Unnamed: 4 Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# 20         NaN   0.002223         NaN         NaN         NaN         NaN
# 21         NaN   0.009163         NaN         NaN         NaN         NaN
# 22         NaN  -0.000669         NaN         NaN         NaN         NaN
# 23         NaN   0.011572         NaN         NaN         NaN         NaN
# 24         NaN   0.067032         NaN         NaN         NaN         NaN
#
#    Unnamed: 10  Unnamed: 11 Unnamed: 12
# ...

# %%
dfbki_neu = dfbki.drop(columns=["index", "Zürcher Index der Wohnbaukosten", "Unnamed: 1"])
dfbki_neu.shape
# Out:
# (25, 11)

# %%
dfbki_neu = dfbki_neu.rename(columns={"Unnamed: 2" : "Jahr", "Unnamed: 3" : "Stand"})

# %%
dfbki_neu2 = dfbki_neu[["Jahr", "Stand"]]
dfbki_neu2
# Out:
#     Jahr   Stand
# 0    NaN     NaN
# 1   Jahr  Stand¹
# 2   2000   887.1
# 3   2001   929.3
# 4   2002   928.4
# 5   2003   899.2
# 6   2004   907.6
# 7   2005   929.5
# 8   2006   944.5
# 9   2007   987.4
# 10  2008  1026.8
# 11  2009  1030.7
# 12  2010  1042.6
# 13  2011  1059.8
# 14  2012  1067.4
# 15  2013  1060.9
# 16  2014  1066.1
# 17  2015  1053.2
# 18  2016  1034.4
# 19  2017  1034.5
# 20  2018  1036.8
# 21  2019  1046.3
# 22  2020  1045.6
# 23  2021  1057.7
# 24  2022  1128.6

# %%
dfbki_neu2.drop(dfbki_neu2.index[[0,1]], inplace=True)
dfbki_neu2
# Out:
# /var/folders/t8/xl0xzpb57bz854gpvcy7rr_r0000gn/T/ipykernel_68793/3387144758.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfbki_neu2.drop(dfbki_neu2.index[[0,1]], inplace=True)
#     Jahr   Stand
# 2   2000   887.1
# 3   2001   929.3
# 4   2002   928.4
# 5   2003   899.2
# 6   2004   907.6
# 7   2005   929.5
# 8   2006   944.5
# 9   2007   987.4
# 10  2008  1026.8
# 11  2009  1030.7
# 12  2010  1042.6
# 13  2011  1059.8
# 14  2012  1067.4
# 15  2013  1060.9
# 16  2014  1066.1
# 17  2015  1053.2
# 18  2016  1034.4
# 19  2017  1034.5
# 20  2018  1036.8
# 21  2019  1046.3
# 22  2020  1045.6
# 23  2021  1057.7
# 24  2022  1128.6

# %%
dfbki_neu2 = dfbki_neu2.reset_index()
dfbki_neu2
# Out:
#     index  Jahr   Stand
# 0       2  2000   887.1
# 1       3  2001   929.3
# 2       4  2002   928.4
# 3       5  2003   899.2
# 4       6  2004   907.6
# 5       7  2005   929.5
# 6       8  2006   944.5
# 7       9  2007   987.4
# 8      10  2008  1026.8
# 9      11  2009  1030.7
# 10     12  2010  1042.6
# 11     13  2011  1059.8
# 12     14  2012  1067.4
# 13     15  2013  1060.9
# 14     16  2014  1066.1
# 15     17  2015  1053.2
# 16     18  2016  1034.4
# 17     19  2017  1034.5
# 18     20  2018  1036.8
# 19     21  2019  1046.3
# 20     22  2020  1045.6
# 21     23  2021  1057.7
# 22     24  2022  1128.6

# %%
dfbki_neu2 = dfbki_neu2.drop(columns=["index"])
dfbki_neu2
# Out:
#     Jahr   Stand
# 0   2000   887.1
# 1   2001   929.3
# 2   2002   928.4
# 3   2003   899.2
# 4   2004   907.6
# 5   2005   929.5
# 6   2006   944.5
# 7   2007   987.4
# 8   2008  1026.8
# 9   2009  1030.7
# 10  2010  1042.6
# 11  2011  1059.8
# 12  2012  1067.4
# 13  2013  1060.9
# 14  2014  1066.1
# 15  2015  1053.2
# 16  2016  1034.4
# 17  2017  1034.5
# 18  2018  1036.8
# 19  2019  1046.3
# 20  2020  1045.6
# 21  2021  1057.7
# 22  2022  1128.6

# %%
dfbki_neu2.dtypes
# Out:
# Jahr     object
# Stand    object
# dtype: object

# %%
dfbki_neu2["Stand"] = dfbki_neu2["Stand"].astype(float)
dfbki_neu2.dtypes
# Out:
# Jahr      object
# Stand    float64
# dtype: object
